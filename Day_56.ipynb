# %% [markdown]
# <a href="https://colab.research.google.com/github/Ykarthikeyan1/day_56/blob/main/Day_56.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import numpy as np
arr4 = np.array([1,2,3,5236])
 
print(arr4.dtype)
 
print (arr4.ndim)
 
print (arr4.shape)
 
print(arr4.size)
# Out:
# int64
# 1
# (4,)
# 4
